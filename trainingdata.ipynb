# %%
# !pip install -U ipywidgets ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.5/983.5 kB 20.0 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.0/214.0 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 51.6 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 4.0.13
#     Uninstalling widgetsnbextension-4.0.13:
#       Successfully uninstalled widgetsnbextension-4.0.13
#   Attempting uninstall: jupyterlab_widgets
#     Found existing installation: jupyterlab_widgets 3.0.13
#     Uninstalling jupyterlab_widgets-3.0.13:
#       Successfully uninstalled jupyterlab_widgets-3.0.13
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 8.1.5
#     Uninstalling ipywidgets-8.1.5:
#       Successfully uninstalled ipywidgets-8.1.5
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !git clone https://github.com/AlwanIndrawan/yolo.git
# Out:
# Cloning into 'yolo'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), 4.79 MiB | 22.11 MiB/s, done.

# %%
model_path = "/kaggle/working/yolo/yolo11n.pt"
model = YOLO(model=model_path)

# %%
import os
os.environ['WANDB_MODE']= 'disabled'

# %%
model.train(data="/kaggle/input/tanamanrimpangv2/data.yaml", 
            epochs=100, 
            batch=8, 
            imgsz=640, 
            project="runs", 
            name="herbale100b8")
# Out:
# Ultralytics 8.3.115 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls /kaggle/working/runs/herbale100b8
# Out:
# F1_curve.png			 labels_correlogram.jpg  train_batch2.jpg
# PR_curve.png			 results.csv		 val_batch0_labels.jpg
# P_curve.png			 results.png		 val_batch0_pred.jpg
# R_curve.png			 train_batch0.jpg	 val_batch1_labels.jpg
# args.yaml			 train_batch1.jpg	 val_batch1_pred.jpg
# confusion_matrix.png		 train_batch18720.jpg	 val_batch2_labels.jpg
# confusion_matrix_normalized.png  train_batch18721.jpg	 val_batch2_pred.jpg
# labels.jpg			 train_batch18722.jpg	 weights

# %%
from IPython.display import Image

Image(filename=f'/kaggle/working/runs/herbale100b8/confusion_matrix.png', width=600)

# %%
Image(filename=f'/kaggle/working/runs/herbale100b8/results.png', width=600)

# %%
Image(filename=f'/kaggle/working/runs/herbale100b8/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=detect mode=val model=/kaggle/working/runs/herbale100b8/weights/best.pt data=/kaggle/input/tanamanrimpangv2/data.yaml
# Out:
# Ultralytics 8.3.115 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 22.0±4.2 MB/s, size: 25.8 KB)
# val: Scanning /kaggle/input/tanamanrimpangv2/valid/labels... 140 images, 0 backg
# WARNING ⚠️ val: Cache directory /kaggle/input/tanamanrimpangv2/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        443      0.996      0.998      0.995      0.842
#                   Jahe         21         45      0.995          1      0.995      0.879
#                 Kencur         28        169          1          1      0.995       0.78
#                 Kunyit         21         47      0.995          1      0.995      0.867
#               Lengkuas         29         99       0.99       0.99      0.995      0.863
# ...

# %%
# !yolo task=detect mode=predict model=/kaggle/working/runs/herbale100b8/weights/best.pt conf=0.5 source=/kaggle/input/tanamanrimpangv2/valid/images save=true
# Out:
# Ultralytics 8.3.115 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/140 /kaggle/input/tanamanrimpangv2/valid/images/IMG_20250423_124208_jpg.rf.57c9252663931b2d1a33b48e08c7338c.jpg: 640x640 1 Jahe, 10.0ms
# image 2/140 /kaggle/input/tanamanrimpangv2/valid/images/IMG_20250423_124339_jpg.rf.9f56e5ba738440a0a8cc50bff56c7ac6.jpg: 640x640 1 Jahe, 9.1ms
# image 3/140 /kaggle/input/tanamanrimpangv2/valid/images/IMG_20250423_124415_jpg.rf.9071a5b0ba36270f967c0a7386668937.jpg: 640x640 1 Jahe, 8.5ms
# image 4/140 /kaggle/input/tanamanrimpangv2/valid/images/IMG_20250423_130516_jpg.rf.1c7322b67e12e8aa71ae1ac021ae5f0c.jpg: 640x640 1 Kunyit, 8.3ms
# image 5/140 /kaggle/input/tanamanrimpangv2/valid/images/IMG_20250423_130528_jpg.rf.f4fe9800ed2496420aac713531ef9e4e.jpg: 640x640 1 Kunyit, 8.4ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/kaggle/working/runs/detect/predict/*.jpg')[:10]:
      display(Image(filename=image_path, height=600))
      print("\n")

# %% [markdown]
# **CONVERT**

# %%
# !pip install onnx2tf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.7/147.7 kB 2.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.6/446.6 kB 14.7 MB/s eta 0:00:00
# ...

# %%
# !pip install onnx-graphsurgeon
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 1.5 MB/s eta 0:00:00
# ...

# %%
# !pip install ai-edge-litert
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 35.2 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !pip install sng4onnx

# %%
# !pip install tflite_support
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 MB 28.0 MB/s eta 0:00:00:00:0100:01
# ...

# %%
import torch
from ultralytics import YOLO

# Load the YOLO11 model
model = YOLO(f"/kaggle/working/runs/herbale100b8/weights/best.pt")
model.export(format='tflite', nms=True)
# Out:
# Ultralytics 8.3.115 🚀 Python-3.10.14 torch-2.4.0 CPU (Intel Xeon 2.00GHz)
# YOLO11n summary (fused): 100 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/kaggle/working/runs/herbale100b8/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (5.2 MB)
# requirements: Ultralytics requirements ['onnxslim>=0.1.31', 'onnxruntime-gpu', 'protobuf>=5'] not found, attempting AutoUpdate...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# apache-beam 2.46.0 requires cloudpickle~=2.2.1, but you have cloudpickle 3.1.0 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
import tensorflow as tf

interpreter = tf.lite.Interpreter(model_path=f"/kaggle/working/runs/herbale100b8/weights/best_saved_model/best_float32.tflite")
interpreter.allocate_tensors()

print("✅ Model Loaded")

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("Input:", input_details[0]['shape'], input_details[0]['dtype'])
for i, output in enumerate(output_details):
    print(f"Output {i}:", output['shape'], output['dtype'])
# Out:
# ✅ Model Loaded
# Input: [  1 640 640   3] <class 'numpy.float32'>
# Output 0: [  1 300   6] <class 'numpy.float32'>
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
from ultralytics import YOLO

model = YOLO(f"/kaggle/working/runs/herbale100b8/weights/best.pt")

print("✅ Jumlah class:", model.model.nc)
print("🧾 Label:", model.model.names)
# Out:
# ✅ Jumlah class: 5
# 🧾 Label: {0: 'Jahe', 1: 'Kencur', 2: 'Kunyit', 3: 'Lengkuas', 4: 'Temulawak'}

# %%
import tensorflow as tf

interpreter = tf.lite.Interpreter(model_path=f"/kaggle/working/runs/herbale100b8/weights/best_saved_model/best_float32.tflite")
interpreter.allocate_tensors()


# Cek input
input_details = interpreter.get_input_details()
print("Input:")
print("  Name :", input_details[0]['name'])
print("  Dtype:", input_details[0]['dtype'])
print("  Shape:", input_details[0]['shape'])

# Cek output
output_details = interpreter.get_output_details()
print("Output:")
print("  Name :", output_details[0]['name'])
print("  Dtype:", output_details[0]['dtype'])
print("  Shape:", output_details[0]['shape'])
# Out:
# Input:
#   Name : images
#   Dtype: <class 'numpy.float32'>
#   Shape: [  1 640 640   3]
# Output:
#   Name : Identity
#   Dtype: <class 'numpy.float32'>
#   Shape: [  1 300   6]

# %%
# !zip -r hasil_training_e100b8.zip /kaggle/working/runs
# Out:
#   adding: kaggle/working/runs/ (stored 0%)
#   adding: kaggle/working/runs/detect/ (stored 0%)
#   adding: kaggle/working/runs/detect/val/ (stored 0%)
#   adding: kaggle/working/runs/detect/val/val_batch1_labels.jpg (deflated 16%)
#   adding: kaggle/working/runs/detect/val/val_batch1_pred.jpg (deflated 15%)
#   adding: kaggle/working/runs/detect/val/R_curve.png (deflated 13%)
#   adding: kaggle/working/runs/detect/val/val_batch0_pred.jpg (deflated 12%)
#   adding: kaggle/working/runs/detect/val/PR_curve.png (deflated 24%)
#   adding: kaggle/working/runs/detect/val/val_batch0_labels.jpg (deflated 13%)
#   adding: kaggle/working/runs/detect/val/val_batch2_pred.jpg (deflated 13%)
#   adding: kaggle/working/runs/detect/val/confusion_matrix.png (deflated 29%)
#   adding: kaggle/working/runs/detect/val/P_curve.png (deflated 20%)
#   adding: kaggle/working/runs/detect/val/confusion_matrix_normalized.png (deflated 28%)
#   adding: kaggle/working/runs/detect/val/F1_curve.png (deflated 12%)
# ...
